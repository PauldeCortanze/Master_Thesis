# %%
# Install hydesign if needed
import importlib
if not importlib.util.find_spec("hydesign"):
    # !pip install git+https://gitlab.windenergy.dtu.dk/TOPFARM/hydesign.git
import sys
sys.path.insert(0, r"C:\Mes documents\DTU\4th Master Thesis\Preparation\hydesign")

# %%
import openmdao.api as om
import hydesign.assembly.hpp_assembly as hpp_assembly
importlib.reload(hpp_assembly)

from hydesign.assembly.hpp_assembly import hpp_model
from hydesign.examples import examples_filepath
import pandas as pd
import os
import hydesign.assembly.hpp_assembly as mod
print(mod.__file__)
# Out:
# C:\Users\pauld\OneDrive\Documents\Mes documents\DTU\4th Master Thesis\HyDesign_Code\Master_Thesis\hydesign\assembly\hpp_assembly.py

# %%
import time

name = "France_good_wind"
examples_sites = pd.read_csv(
    f"{examples_filepath}examples_sites.csv", index_col=0, sep=";"
)
ex_site = examples_sites.loc[examples_sites.name == name]

longitude = ex_site["longitude"].values[0]
latitude = ex_site["latitude"].values[0]
altitude = ex_site["altitude"].values[0]

sim_pars_fn = examples_filepath + ex_site["sim_pars_fn"].values[0]
input_ts_fn = examples_filepath + ex_site["input_ts_fn"].values[0]

hpp = hpp_model(
    latitude=latitude,
    longitude=longitude,
    altitude=altitude,
    sim_pars_fn=sim_pars_fn,
    input_ts_fn=input_ts_fn,
)

start = time.time()

x = [
    55.0,
    257.0,
    10.000000000000002,
    10.0,
    5.916666666666667,
    75.0,
    28.125,
    191.25,
    1.4791666666666665,
    27.0,
    4.0,
    8.75,
]

outs = hpp.evaluate(*x)

hpp.print_design()

end = time.time()
print("exec. time [min]:", (end - start) / 60)

print(hpp.prob["NPV_over_CAPEX"])
# Out:
# Fixed parameters on the site
# -------------------------------
# longitude = -0.864258
# latitude = 48.744116
# altitude = 302.0
#
# Design:
# ---------------
# clearance [m]: 55.000
# sp [W/m2]: 257.000
# p_rated [MW]: 10.000
# Nwt: 10.000
# wind_MW_per_km2 [MW/km2]: 5.917
# solar_MW [MW]: 75.000
# surface_tilt [deg]: 28.125
# surface_azimuth [deg]: 191.250
# DC_AC_ratio: 1.479
# b_P [MW]: 27.000
# b_E_h [h]: 4.000
# cost_of_battery_P_fluct_in_peak_price_ratio: 8.750
#
#
# NPV_over_CAPEX: 0.562
# NPV [MEuro]: 119.099
# IRR: 0.104
# LCOE [Euro/MWh]: 39.763
# Revenues [MEuro]: 18.503
# CAPEX [MEuro]: 211.788
# OPEX [MEuro]: 2.932
# Wind CAPEX [MEuro]: 120.585
# Wind OPEX [MEuro]: 2.432
# PV CAPEX [MEuro]: 24.797
# PV OPEX [MEuro]: 0.499
# Batt CAPEX [MEuro]: 10.354
# Batt OPEX [MEuro]: 0.000
# Shared CAPEX [MEuro]: 56.052
# Shared OPEX [MEuro]: 0.000
# penalty lifetime [MEuro]: 0.000
# Mean Annual Electricity Sold [GWh]: 474.290
# GUF: 0.180
# grid [MW]: 300.000
# wind [MW]: 100.000
# ...
